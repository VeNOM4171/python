# %%
import pandas as pd

# %% [raw]
# Q1. Write a Pandas program to get the powers of an array values element-wise.
# Note: First array elements raised to powers from second array
# Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}

# %%
sample_data = pd.DataFrame({'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]})
sample_data
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %% [raw]
# Q2. Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels.
# Sample Python dictionary data and list labels:
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Expected Output:
# attempts name qualify score
# a 1 Anastasia yes 12.5
# b 3 Dima no 9.0
# .... i 2 Kevin no 8.0
# j 1 Jonas yes 19.0

# %%
import numpy as np

# %%
exam_data = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']})
exam_data
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
exam_data
# Out:
# {'name': ['Anastasia',
#   'Dima',
#   'Katherine',
#   'James',
#   'Emily',
#   'Michael',
#   'Matthew',
#   'Laura',
#   'Kevin',
#   'Jonas'],
#  'score': [12.5, 9, 16.5, nan, 9, 20, 14.5, nan, 8, 19],
#  'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#  'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# %%
label = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
label
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
result = pd.DataFrame(exam_data, index=label)
result
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
exam_data = {'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
              'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes'],
             'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19]
}
result = pd.DataFrame(exam_data, index=label)
result
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %% [raw]
# Q3. Write a Pandas program to display a summary of the basic information about a specified DataFrame and its data.
# Sample Python dictionary data and list labels:
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Expected Output:
# Summary of the basic information about this DataFrame and its data:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# .... dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
result
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   attempts  10 non-null     int64
#  1   name      10 non-null     object
#  2   qualify   10 non-null     object
#  3   score     8 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [raw]
# Q4. Write a Pandas program to get the first 3 rows of a given DataFrame.
# Expected Output:
# First three rows of the data frame:
# attempts name qualify score
# a 1 Anastasia yes 12.5
# b 3 Dima no 9.0
# c 2 Katherine yes 16.5

# %%
result.head(3)
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5

# %% [raw]
# Q5. Write a Pandas program to select the 'name' and 'score' columns from the following DataFrame.

# %%
result
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %%
sliced_dataframe = result[['name','score']]
sliced_dataframe
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %% [raw]
# Q6. Write a Pandas program to select the specified columns and rows from a given data frame.

# %%
result
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %%
get_col_row = result[result.columns[1:3]].iloc[3:7]
get_col_row
# Out:
#       name qualify
# d    James      no
# e    Emily      no
# f  Michael     yes
# g  Matthew     yes

# %% [raw]
# Q7. Write a Pandas program to select the rows where the number of attempts in the examination is greater than 2.

# %%
result
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %%
check = result[result['attempts'] > 2]
check
# Out:
#    attempts     name qualify  score
# b         3     Dima      no    9.0
# d         3    James      no    NaN
# f         3  Michael     yes   20.0

# %% [raw]
# Q8. Write a Pandas program to count the number of rows and columns of a DataFrame

# %%
result
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %%
total_rows = len(result.axes[0])
total_cols = len(result.axes[1])
print(f'Total Rows : {total_rows}\nTotal Cols : {total_cols}')
# Out:
# Total Rows : 10
# Total Cols : 4

# %% [raw]
# Q9. Write a Pandas program to select the rows where the score is missing, i.e. is NaN.

# %%
result
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %%
misprint = result[result['score'].isnull()]
misprint
# Out:
#    attempts   name qualify  score
# d         3  James      no    NaN
# h         1  Laura      no    NaN

# %% [raw]
# Q10. Write a Pandas program to select the rows the score is between 15 and 20 (inclusive).

# %%
desired_score = result[result['score'].between(15,20)]
desired_score
# Out:
#    attempts       name qualify  score
# c         2  Katherine     yes   16.5
# f         3    Michael     yes   20.0
# j         1      Jonas     yes   19.0
